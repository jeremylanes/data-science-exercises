# %% [markdown]
# # Drop Column

# %%
import pandas as pd
df = pd.read_csv('../data.csv')

# %%
df

# %%
df.columns

# %%
df.drop('ip_address', axis=1, inplace=True)

# %%
df

# %%
df.set_index('gender', inplace=True)

# %%
df

# %%
df.drop('Male', axis=0, inplace=True)

# %%
df.head()

# %%
df.drop(['date', 'first_name', 'last_name'], axis=1, inplace=True)

# %%
df.tail()

# %%
del df['id']

# %%
df.head()
