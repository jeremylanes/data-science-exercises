# %% [markdown]
# # Data Analyse

# %%
import pandas as pd
df = pd.read_csv('../data.csv')

# %%
df.head()

# %%
df.tail()

# %%
df.head(10)

# %%
df.shape

# %%
df.columns.tolist()

# %%
df.index

# %%
df.set_index('email', inplace=True)

# %%
df

# %%
df.index
