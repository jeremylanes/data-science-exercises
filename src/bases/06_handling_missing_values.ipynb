# %% [markdown]
# # Handing Missing Values

# %%
import pandas as pd
df = pd.read_csv('../data.csv')

# %%
df.isnull()

# %%
df.notnull()

# %%
df_tax_filter = df.tax.notnull()

# %%
df[df_tax_filter]

# %%
df.tax.fillna(0)

# %%
df.dropna(subset=['tax', 'country'], inplace=True)

# %%
df
